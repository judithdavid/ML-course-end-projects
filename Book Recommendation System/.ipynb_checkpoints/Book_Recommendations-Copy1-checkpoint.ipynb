# %%
import os
import pandas as pd
import numpy as np

# %%
for each in os.listdir():
    print(each)
# Out:
# BX-Book-Ratings.csv
# BX-Books.csv
# BX-Users.csv
# Book_Recommendations.ipynb
# .ipynb_checkpoints
# Recommend.csv

# %%
rating = "BX-Book-Ratings.csv"
book = "BX-Books.csv"
users = "BX-Users.csv"

# %%
r = pd.read_csv(rating,encoding="latin-1")
b = pd.read_csv(book,encoding="latin-1")
u = pd.read_csv(users,encoding="latin-1")

# %%
r
# Out:
#          user_id        isbn  rating
# 0         276725  034545104X       0
# 1         276726   155061224       5
# 2         276727   446520802       0
# 3         276729  052165615X       3
# 4         276729   521795028       6
# ...          ...         ...     ...
# 1048570   250764   451410777       0
# 1048571   250764   452264464       8
# 1048572   250764  048623715X       0
# 1048573   250764   486256588       0
# 1048574   250764   515069434       0
#
# [1048575 rows x 3 columns]

# %%
b
# Out:
#               isbn                                         book_title  \
# 0        195153448                                Classical Mythology
# 1          2005018                                       Clara Callan
# 2         60973129                               Decision in Normandy
# 3        374157065  Flu: The Story of the Great Influenza Pandemic...
# 4        393045218                             The Mummies of Urumchi
# ...            ...                                                ...
# 271374   440400988                         There's a Bat in Bunk Five
# 271375   525447644                            From One to One Hundred
# 271376  006008667X  Lily Dale : The True Story of the Town that Ta...
# 271377   192126040                        Republic (World's Classics)
# 271378   767409752  A Guided Tour of Rene Descartes' Meditations o...
#
#                  book_author year_of_publication  \
# 0         Mark P. O. Morford                2002
# ...

# %%
u
# Out:
#        user_id                            Location   Age
# 0            1                  nyc, new york, usa   NaN
# 1            2           stockton, california, usa  18.0
# 2            3     moscow, yukon territory, russia   NaN
# 3            4           porto, v.n.gaia, portugal  17.0
# 4            5  farnborough, hants, united kingdom   NaN
# ...        ...                                 ...   ...
# 278854  278854               portland, oregon, usa   NaN
# 278855  278855  tacoma, washington, united kingdom  50.0
# 278856  278856           brampton, ontario, canada   NaN
# 278857  278857           knoxville, tennessee, usa   NaN
# 278858  278858                dublin, n/a, ireland   NaN
#
# [278859 rows x 3 columns]

# %%
# 1. Read the books dataset and explore it

# %%
## Check unique values of yearOfPublication

# %%
b['year_of_publication'].unique()

#has lot of special chars - need cleaning
# Out:
# array(['2002', '2001', '1991', '1999', '2000', '1993', '1996', '1988',
#        '2004', '1998', '1994', '2003', '1997', '1983', '1979', '1995',
#        '1982', '1985', '1992', '1986', '1978', '1980', '1952', '1987',
#        '1990', '1981', '1989', '1984', '0', '1968', '1961', '1958',
#        '1974', '1976', '1971', '1977', '1975', '1965', '1941', '1970',
#        '1962', '1973', '1972', '1960', '1966', '1920', '1956', '1959',
#        '1953', '1951', '1942', '1963', '1964', '1969', '1954', '1950',
#        '1967', '2005', '1957', '1940', '1937', 'John Peterman', '1955',
#        '1946', '1936', '1930', '2011', '1925', '1948', '1943', '1947',
#        '1945', '1923', '2020', '1939', '1926', '1938', '2030',
#        '\\"Freedom Song\\""', '1911', '1904', '1949', 'Frank Muir',
#        '1932', '1928', '1929', '1927', '1931', '1914', '2050', '1934',
#        '1910', 'ROBERT A. WILSON', '1933', '1902', 'Karen T. Whittenburg',
# ...

# %%
## Check the rows having 'DK Publishing Inc' as yearOfPublication¶

# %%
b.loc[b['year_of_publication']== 'DK Publishing Inc',:]
# Out:
#               isbn                                         book_title  \
# 209550  078946697X  DK Readers: Creating the X-Men, How It All Beg...
# 221691   789466953  DK Readers: Creating the X-Men, How Comic Book...
#
#        book_author year_of_publication  \
# 209550        2000   DK Publishing Inc
# 221691        2000   DK Publishing Inc
#
#                                                 publisher
# 209550  http://images.amazon.com/images/P/078946697X.0...
# 221691  http://images.amazon.com/images/P/0789466953.0...

# %%
print("Rating Cols \n", r.columns)
print("Books Cols \n", b.columns)
print("Users Cols \n", u.columns)
# Out:
# Rating Cols
#  Index(['user_id', 'isbn', 'rating'], dtype='object')
# Books Cols
#  Index(['isbn', 'book_title', 'book_author', 'year_of_publication',
#        'publisher'],
#       dtype='object')
# Users Cols
#  Index(['user_id', 'Location', 'Age'], dtype='object')

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
df_final = pd.merge(r,b,on='isbn')

# %%
df_final
# Out:
#         user_id        isbn  rating  \
# 0        276725  034545104X       0
# 1          2313  034545104X       5
# 2          6543  034545104X       0
# 3          8680  034545104X       5
# 4         10314  034545104X       9
# ...         ...         ...     ...
# 941143   250764   440106575       0
# 941144   250764   451157516       0
# 941145   250764  048623715X       0
# 941146   250764   486256588       0
# 941147   250764   515069434       0
#
#                                                book_title        book_author  \
# 0                                    Flesh Tones: A Novel         M. J. Rose
# 1                                    Flesh Tones: A Novel         M. J. Rose
# 2                                    Flesh Tones: A Novel         M. J. Rose
# 3                                    Flesh Tones: A Novel         M. J. Rose
# 4                                    Flesh Tones: A Novel         M. J. Rose
# ...

# %%
df_final = df_final[['user_id', 'isbn', 'rating']]

# %%
df_final = df_final.head(1000)
df_final
# Out:
#      user_id        isbn  rating
# 0     276725  034545104X       0
# 1       2313  034545104X       5
# 2       6543  034545104X       0
# 3       8680  034545104X       5
# 4      10314  034545104X       9
# ..       ...         ...     ...
# 995    36003   609801279       0
# 996    52425   609801279       0
# 997    73681   609801279       8
# 998    86481   609801279       0
# 999   100119   609801279       0
#
# [1000 rows x 3 columns]

# %% [markdown]
# ## Convert ISBN variable to numeric type in order

# %%
# Convert and print length of isbn list
isbn_list = df_final.isbn.unique()
print(" Length of isbn List:", len(isbn_list))
def get_isbn_numeric_id(isbn):
    #print ("  isbn is:" , isbn)
    itemindex = np.where(isbn_list==isbn)
    return itemindex[0][0]
# Out:
#  Length of isbn List: 16

# %%
# Convert and print length of user_id list
userid_list = df_final.user_id.unique()
print(" Length of user_id List:", len(userid_list))
def get_user_id_numeric_id(user_id):
    #print ("  isbn is:" , isbn)
    itemindex = np.where(userid_list==user_id)
    return itemindex[0][0]
# Out:
#  Length of user_id List: 832

# %% [markdown]
# ###  Convert both user_id and isbn to ordered list i.e. from 0...n-1

# %%
df_final['user_id_order'] = df_final['user_id'].apply(get_user_id_numeric_id)

# %%
df_final['isbn_id'] = df_final['isbn'].apply(get_isbn_numeric_id)
df_final.head()
# Out:
#    user_id        isbn  rating  user_id_order  isbn_id
# 0   276725  034545104X       0              0        0
# 1     2313  034545104X       5              1        0
# 2     6543  034545104X       0              2        0
# 3     8680  034545104X       5              3        0
# 4    10314  034545104X       9              4        0

# %%
## Re-index columns to build matrix

# %%
# Reindexing the columns
new_col_order = ['user_id_order', 'isbn_id', 'rating', 'book_title', 'book_author','year_of_publication','publisher','isbn','user_id']
df_final = df_final.reindex(columns= new_col_order)
df_final.head()
# Out:
#    user_id_order  isbn_id  rating  book_title  book_author  \
# 0              0        0       0         NaN          NaN
# 1              1        0       5         NaN          NaN
# 2              2        0       0         NaN          NaN
# 3              3        0       5         NaN          NaN
# 4              4        0       9         NaN          NaN
#
#    year_of_publication  publisher        isbn  user_id
# 0                  NaN        NaN  034545104X   276725
# 1                  NaN        NaN  034545104X     2313
# 2                  NaN        NaN  034545104X     6543
# 3                  NaN        NaN  034545104X     8680
# 4                  NaN        NaN  034545104X    10314

# %%
### Alternate Method

# %%
from sklearn.preprocessing import LabelEncoder

# %%
LE = LabelEncoder()

# %%
df_final['isbn_le_idx'] = LE.fit_transform(df_final['isbn'])

# %%
df_final['user_le_idx'] = LE.fit_transform(df_final['user_id'])

# %%
df_final.head()
# Out:
#    user_id        isbn  rating  user_id_order  isbn_id  isbn_le_idx  \
# 0   276725  034545104X       0              0        0            0
# 1     2313  034545104X       5              1        0            0
# 2     6543  034545104X       0              2        0            0
# 3     8680  034545104X       5              3        0            0
# 4    10314  034545104X       9              4        0            0
#
#    user_le_idx
# 0          820
# 1            8
# 2           17
# 3           24
# 4           30

# %%
df_final['isbn'].unique()
# Out:
# array(['034545104X', '155061224', '446520802', '052165615X', '521795028',
#        '2080674722', '038550120X', '425115801', '449006522', '553561618',
#        '055356451X', '786013990', '786014512', '60517794', '451192001',
#        '609801279'], dtype=object)

# %%
df_final[df_final['isbn']=='786014512'][['isbn_le_idx','isbn_id']]
# Out:
#      isbn_le_idx  isbn_id
# 840           15       12
# 841           15       12
# 842           15       12
# 843           15       12
# 844           15       12
# 845           15       12
# 846           15       12
# 847           15       12
# 848           15       12
# 849           15       12
